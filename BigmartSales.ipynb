# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from xgboost import XGBRFRegressor
from sklearn import metrics

# %%
big_mart_data = pd.read_csv(r"C:\Users\abang\Downloads\archive (9)\Train.csv")
big_mart_data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
big_mart_data.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
big_mart_data.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
categorical_data = []
for x in big_mart_data.dtypes.index:
    if big_mart_data.dtypes[x] == 'object':
        categorical_data.append(x)
categorical_data
# Out:
# ['Item_Identifier',
#  'Item_Fat_Content',
#  'Item_Type',
#  'Outlet_Identifier',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type']

# %%
Item_Weight_mean = big_mart_data.pivot_table(values='Item_Weight',index='Item_Identifier')
Item_Weight_mean
# Out:
#                  Item_Weight
# Item_Identifier
# DRA12                 11.600
# DRA24                 19.350
# DRA59                  8.270
# DRB01                  7.390
# DRB13                  6.115
# ...                      ...
# NCZ30                  6.590
# NCZ41                 19.850
# NCZ42                 10.500
# NCZ53                  9.600
# NCZ54                 14.650
#
# [1555 rows x 1 columns]

# %%
miss_bool=big_mart_data['Item_Weight'].isnull()

# %%
miss_bool
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8518    False
# 8519    False
# 8520    False
# 8521    False
# 8522    False
# Name: Item_Weight, Length: 8523, dtype: bool

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
for i, item in enumerate(big_mart_data['Item_Identifier']):
    if miss_bool[i]:
        if item in Item_Weight_mean:
            big_mart_data['Item_Weight'][i]=Item_Weight_mean.loc[item]['Item_Weight']
        else:
            big_mart_data['Item_Weight'][i]=big_mart_data['Item_Weight'].mean()

# %%
big_mart_data['Item_Weight'].isnull().sum()
# Out:
# 0

# %%
for col in categorical_data:
    print(col)
    print(big_mart_data[col].value_counts())
    print()
# Out:
# Item_Identifier
# FDW13    10
# FDG33    10
# NCY18     9
# FDD38     9
# DRE49     9
#          ..
# FDY43     1
# FDQ60     1
# FDO33     1
# DRF48     1
# FDC23     1
# Name: Item_Identifier, Length: 1559, dtype: int64
#
# Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64
#
# Item_Type
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64
#
# Outlet_Identifier
# OUT027    935
# OUT013    932
# ...

# %%
outlet_size_mode = big_mart_data.pivot_table(values='Outlet_Size',columns='Outlet_Type',aggfunc=(lambda x:x.mode()[0]))

# %%
outlet_size_mode
# Out:
# Outlet_Type Grocery Store Supermarket Type1 Supermarket Type2  \
# Outlet_Size         Small             Small            Medium
#
# Outlet_Type Supermarket Type3
# Outlet_Size            Medium

# %%
miss_bool = big_mart_data['Outlet_Size'].isnull()
big_mart_data.loc[miss_bool,'Outlet_Size']=big_mart_data.loc[miss_bool,'Outlet_Type'].apply(lambda x:outlet_size_mode)

# %%
big_mart_data['Outlet_Size'].isnull().sum()
# Out:
# 0

# %%
sum(big_mart_data['Item_Visibility'] == 0)
# Out:
# 526

# %%
big_mart_data.loc[:,'Item_Visibility'].replace([0],[big_mart_data['Item_Visibility'].mean()],inplace=True)

# %%
sum(big_mart_data['Item_Visibility'] == 0)
# Out:
# 0

# %%
big_mart_data['Item_Fat_Content'].replace({'LF':'Low Fat','reg':'Regular','low fat':'Low Fat'},inplace=True)

# %%
big_mart_data['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64

# %%
cor=big_mart_data.corr()

# %%
plt.figure(figsize=(5,5))
sns.distplot(big_mart_data['Item_Weight'])
plt.show()

# %%
big_mart_data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.066132
# 4              NCD19        8.930          Low Fat         0.066132
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
plt.figure(figsize=(5,5))
sns.distplot(big_mart_data['Item_Visibility'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.distplot(big_mart_data['Item_MRP'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.distplot(big_mart_data['Outlet_Establishment_Year'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x='Item_Fat_Content',data=big_mart_data)
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.countplot(x='Item_Type',data=big_mart_data)
plt.show()

# %% [markdown]
# Label Encoding

# %%
big_mart_data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.066132
# 4              NCD19        8.930          Low Fat         0.066132
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
encoder = LabelEncoder()

# %%
big_mart_data['Item_Identifier']=encoder.fit_transform(big_mart_data['Item_Identifier'])

# %%
big_mart_data['Item_Weight']=encoder.fit_transform(big_mart_data['Item_Weight'])

# %%
big_mart_data['Item_Type']=encoder.fit_transform(big_mart_data['Item_Type'])

# %%
big_mart_data['Outlet_Size']=encoder.fit_transform(big_mart_data['Outlet_Size'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\sklearn\utils\_encode.py:170, in _unique_python(values, return_inverse, return_counts)
#     169 try:
# --> 170     uniques_set = set(values)
#     171     uniques_set, missing_values = _extract_missing(uniques_set)
#
# TypeError: unhashable type: 'DataFrame'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 big_mart_data['Outlet_Size']=encoder.fit_transform(big_mart_data['Outlet_Size'])
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\_set_output.py:142, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     140 @wraps(f)
#     141 def wrapped(self, X, *args, **kwargs):
# --> 142     data_to_wrap = f(self, X, *args, **kwargs)
# ...

# %%
big_mart_data['Outlet_Size'].value_counts()
# Out:
# Medium             2793
# [Grocery Store]    2410
# Small              2388
# High                932
# Name: Outlet_Size, dtype: int64

# %%
big_mart_data['Outlet_Size'].drop([Grocery Store],axis=0)
# Out:
#   Cell In[76], line 1
#     big_mart_data['Outlet_Size'].drop([Grocery Store],axis=1)
#                                        ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
